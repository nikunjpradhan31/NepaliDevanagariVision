# %%
import os
import unicodedata
import random
import math
from PIL import Image, ImageDraw, ImageFont, ImageFilter, ImageOps
import numpy as np
import csv

corpus_file = "ne.txt"         # your Devanagari text corpus
fonts_dir = "fonts/static"           # folder with .ttf/.otf fonts
output_images = "data/images"
output_text = "data/"

num_images = 10000              # total number of images to generate
max_lines_per_image = 25      # max number of lines to concatenate per image
image_size = (256, 64)         # width x height
font_size_range = (32, 48)     # min and max font size
os.makedirs(output_images, exist_ok=True)
os.makedirs(output_text, exist_ok=True)

# %%
def apply_skew(img, max_angle=5):
    """Random horizontal skew using affine transform."""
    angle = random.uniform(-max_angle, max_angle)
    return img.transform(
        img.size,
        Image.AFFINE,
        (1, math.tan(math.radians(angle)), 0, 0, 1, 0),
        resample=Image.BICUBIC
    )

def apply_blur(img, max_radius=1.5):
    """Random Gaussian blur."""
    radius = random.uniform(0, max_radius)
    if radius > 0:
        img = img.filter(ImageFilter.GaussianBlur(radius=radius))
    return img

def apply_rotation(img, max_angle=5):
    """Random rotation."""
    angle = random.uniform(-max_angle, max_angle)
    return img.rotate(angle, expand=True, fillcolor="white")

def change_text_color(draw, x, y, text, font, colors=["black"]):
    """Random text color from list."""
    fill = random.choice(colors)
    draw.text((x, y), text, font=font, fill=fill)

# def apply_sin_cos_distortion(img, amplitude_range=(2,5), frequency_range=(0.05,0.15)):
#     """Apply vertical sin/cos wave distortion."""
#     arr = np.array(img)
#     h, w = arr.shape[:2]
#     amplitude = random.uniform(*amplitude_range)
#     frequency = random.uniform(*frequency_range)
    
#     new_arr = np.zeros_like(arr)
#     for i in range(h):
#         shift = int(amplitude * math.sin(2*math.pi*frequency*i))
#         new_arr[i] = np.roll(arr[i], shift, axis=0)
#     return Image.fromarray(new_arr)

def decenter_text(x, y, text_width, text_height, img_width, img_height, margin=10):
    """Randomly decenter text within image."""
    max_x = max(img_width - text_width - margin, margin)
    max_y = max(img_height - text_height - margin, margin)
    x = random.randint(margin, max_x)
    y = random.randint(margin, max_y)
    return x, y

def adjust_char_spacing(draw, x, y, text, font, spacing_range=(0, 5), fill="black"):
    """Draw text with random character spacing using textbbox."""
    for char in text:
        draw.text((x, y), char, font=font, fill=fill)
        # measure character width using textbbox
        bbox = draw.textbbox((x, y), char, font=font)
        char_width = bbox[2] - bbox[0]
        spacing = random.randint(*spacing_range)
        x += char_width + spacing
    return x, y

def center_and_resize_image(img, target_size=(1156, 64)):
    """
    Resize the image to fit inside target_size while maintaining aspect ratio.
    If the image is smaller, center it on a black background of target_size.
    """
    target_w, target_h = target_size
    img_w, img_h = img.size

    # If image is larger — scale it down
    if img_w > target_w or img_h > target_h:
        img.thumbnail((target_w, target_h), Image.LANCZOS)

    # Create black background
    new_img = Image.new("RGB", (target_w, target_h), color="black")

    # Center image
    paste_x = (target_w - img.width) // 2
    paste_y = (target_h - img.height) // 2
    new_img.paste(img, (paste_x, paste_y))

    return new_img

# %%
def draw_text(text, fontfile, output_path, base_image_size):
    text = unicodedata.normalize("NFC", text)
    
    # Start with a random font size
    font_size = random.randint(20, 48)
    pil_font = ImageFont.truetype(fontfile, font_size)
    
    # Temporary image to measure text width
    temp_img = Image.new("RGB", base_image_size, color="white")
    draw = ImageDraw.Draw(temp_img)
    bbox = draw.textbbox((0, 0), text, font=pil_font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]
    
    # Shrink font if too wide
    while text_width + 20 > base_image_size[0] and font_size > 20:
        font_size -= 1
        pil_font = ImageFont.truetype(fontfile, font_size)
        bbox = draw.textbbox((0, 0), text, font=pil_font)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]
    
    # Dynamically adjust image width
    img_width = max(base_image_size[0], text_width + 20)
    img_height = base_image_size[1]
    
    # Create the final image
    img = Image.new("RGB", (img_width, img_height), color="white")
    draw = ImageDraw.Draw(img)
    
    # Random decentering
    x, y = decenter_text(0, 0, text_width, text_height, img_width, img_height)
    
    # Draw text
    draw.text((x, y), text, font=pil_font, fill="black")
    
    # Apply random augmentations
    if random.random() < 0.5:
        img = apply_skew(img)
    if random.random() < 0.5:
        img = apply_blur(img)
    if random.random() < 0.3:
        img = apply_rotation(img)
    # if random.random() < 0.3:
    #     img = apply_sin_cos_distortion(img)
    img = center_and_resize_image(img, (1156, 64))
    img.save(output_path)

def generate_labels_csv(base_dir):
    """
    For each split folder (train, val, test) inside base_dir,
    reads gt.txt and creates labels.csv with columns: filename, words
    """
    for split in ["train", "val", "test"]:
        split_dir = os.path.join(base_dir, split)
        gt_path = os.path.join(split_dir, "gt.txt")
        csv_path = os.path.join(split_dir, "labels.csv")

        if not os.path.exists(gt_path):
            print(f"⚠️ No gt.txt found for {split}")
            continue

        rows = []
        with open(gt_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                filename, text = line.split(" ", 1)
                rows.append((filename, text))

        # Write CSV
        with open(csv_path, "w", newline='', encoding="utf-8") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["filename", "words"])
            writer.writerows(rows)

        print(f"✅ Created {csv_path} with {len(rows)} entries")

# %%
gt_file_path = os.path.join(output_text, "gt.txt")

with open(corpus_file, "r", encoding="utf-8") as f:
    lines = [line.strip() for line in f if line.strip()]

font_files = [os.path.join(fonts_dir, f) for f in os.listdir(fonts_dir)
              if f.lower().endswith((".ttf", ".otf"))]

counter = 0
with open(gt_file_path, "w", encoding="utf-8") as gt_file:
    for _ in range(num_images):
        # pick random number of lines to concatenate
        num_lines = random.randint(1, max_lines_per_image)
        selected_lines = random.choices(lines, k=num_lines)
        text = " ".join(selected_lines)  # concatenate with spaces
        
        font_file = random.choice(font_files)
        file_name = f"image_{counter:05d}.jpg"
        output_path = os.path.join(output_images, file_name)
        
        draw_text(text, font_file, output_path, image_size)
        
        # write to gt.txt
        gt_file.write(f"{file_name} {text}\n")
        
        counter += 1

print(f"Generated {counter} images in {output_images}")
print(f"GT file saved at: {gt_file_path}")
# Out:
# Generated 10000 images in data/images
# GT file saved at: data/gt.txt

# %%
for file in os.listdir(output_images):
    if file.endswith(".jpg"):
        img_path = os.path.join(output_images, file)
        img = Image.open(img_path)
        img = center_and_resize_image(img, (1156, 64))
        img.save(img_path)

# %%
import os
import random
import shutil

dataset_dir = "data"         # folder containing images + gt.txt
image_path = os.path.join(dataset_dir, "images")
output_base = "dataset/"         # where train/val/test folders go
train_ratio, val_ratio, test_ratio = 0.6, 0.2, 0.2
# ----------------

gt_path = os.path.join(dataset_dir, "gt.txt")

# Read all lines (filename + text)
with open(gt_path, "r", encoding="utf-8") as f:
    entries = [line.strip() for line in f if line.strip()]

# Shuffle entries for randomness
random.shuffle(entries)

# Split indices
total = len(entries)
train_end = int(total * train_ratio)
val_end = train_end + int(total * val_ratio)

train_entries = entries[:train_end]
val_entries = entries[train_end:val_end]
test_entries = entries[val_end:]

splits = {
    "train": train_entries,
    "val": val_entries,
    "test": test_entries
}

# Create split directories
for split_name, split_data in splits.items():
    split_dir = os.path.join(output_base, split_name)
    os.makedirs(split_dir, exist_ok=True)
    
    split_gt = os.path.join(split_dir, "gt.txt")
    with open(split_gt, "w", encoding="utf-8") as gt_file:
        for entry in split_data:
            img_name = entry.split(" ", 1)[0]
            src_img = os.path.join(image_path, img_name)
            dst_img = os.path.join(split_dir, img_name)
        
            # Copy image
            print(src_img, "->", dst_img)

            if os.path.exists(src_img):
                shutil.copy(src_img, dst_img)
            
            # Write GT line
            gt_file.write(entry + "\n")

print(f"✅ Split complete! Results saved in '{output_base}'")
print(f"Train: {len(train_entries)}, Val: {len(val_entries)}, Test: {len(test_entries)}")
generate_labels_csv(output_base)
# Out:
# data/images/image_01006.jpg -> dataset/train/image_01006.jpg
# data/images/image_00840.jpg -> dataset/train/image_00840.jpg
# data/images/image_09473.jpg -> dataset/train/image_09473.jpg
# data/images/image_01850.jpg -> dataset/train/image_01850.jpg
# data/images/image_09971.jpg -> dataset/train/image_09971.jpg
# data/images/image_04203.jpg -> dataset/train/image_04203.jpg
# data/images/image_04843.jpg -> dataset/train/image_04843.jpg
# data/images/image_03550.jpg -> dataset/train/image_03550.jpg
# data/images/image_09461.jpg -> dataset/train/image_09461.jpg
# data/images/image_00264.jpg -> dataset/train/image_00264.jpg
# data/images/image_08422.jpg -> dataset/train/image_08422.jpg
# data/images/image_02634.jpg -> dataset/train/image_02634.jpg
# data/images/image_05301.jpg -> dataset/train/image_05301.jpg
# data/images/image_06692.jpg -> dataset/train/image_06692.jpg
# data/images/image_01742.jpg -> dataset/train/image_01742.jpg
# data/images/image_03361.jpg -> dataset/train/image_03361.jpg
# data/images/image_02173.jpg -> dataset/train/image_02173.jpg
# data/images/image_04043.jpg -> dataset/train/image_04043.jpg
# data/images/image_01165.jpg -> dataset/train/image_01165.jpg
# data/images/image_06379.jpg -> dataset/train/image_06379.jpg
# data/images/image_07827.jpg -> dataset/train/image_07827.jpg
# data/images/image_05881.jpg -> dataset/train/image_05881.jpg
# data/images/image_01494.jpg -> dataset/train/image_01494.jpg
# data/images/image_00557.jpg -> dataset/train/image_00557.jpg
# data/images/image_03703.jpg -> dataset/train/image_03703.jpg
# data/images/image_09377.jpg -> dataset/train/image_09377.jpg
# data/images/image_08711.jpg -> dataset/train/image_08711.jpg
# data/images/image_02729.jpg -> dataset/train/image_02729.jpg
# data/images/image_01136.jpg -> dataset/train/image_01136.jpg
# data/images/image_00430.jpg -> dataset/train/image_00430.jpg
# data/images/image_06738.jpg -> dataset/train/image_06738.jpg
# data/images/image_02785.jpg -> dataset/train/image_02785.jpg
# data/images/image_08871.jpg -> dataset/train/image_08871.jpg
# data/images/image_00348.jpg -> dataset/train/image_00348.jpg
# data/images/image_08378.jpg -> dataset/train/image_08378.jpg
# data/images/image_02315.jpg -> dataset/train/image_02315.jpg
# data/images/image_09985.jpg -> dataset/train/image_09985.jpg
# data/images/image_01322.jpg -> dataset/train/image_01322.jpg
# data/images/image_02419.jpg -> dataset/train/image_02419.jpg
# data/images/image_05151.jpg -> dataset/train/image_05151.jpg
# data/images/image_04584.jpg -> dataset/train/image_04584.jpg
# data/images/image_01594.jpg -> dataset/train/image_01594.jpg
# data/images/image_03496.jpg -> dataset/train/image_03496.jpg
# data/images/image_00656.jpg -> dataset/train/image_00656.jpg
# data/images/image_02059.jpg -> dataset/train/image_02059.jpg
# data/images/image_04732.jpg -> dataset/train/image_04732.jpg
# data/images/image_04517.jpg -> dataset/train/image_04517.jpg
# data/images/image_02593.jpg -> dataset/train/image_02593.jpg
# data/images/image_03692.jpg -> dataset/train/image_03692.jpg
# data/images/image_00750.jpg -> dataset/train/image_00750.jpg
# data/images/image_07193.jpg -> dataset/train/image_07193.jpg
# data/images/image_05059.jpg -> dataset/train/image_05059.jpg
# data/images/image_01826.jpg -> dataset/train/image_01826.jpg
# data/images/image_07475.jpg -> dataset/train/image_07475.jpg
# data/images/image_04493.jpg -> dataset/train/image_04493.jpg
# data/images/image_08059.jpg -> dataset/train/image_08059.jpg
# data/images/image_00843.jpg -> dataset/train/image_00843.jpg
# data/images/image_08342.jpg -> dataset/train/image_08342.jpg
# data/images/image_06686.jpg -> dataset/train/image_06686.jpg
# data/images/image_08608.jpg -> dataset/train/image_08608.jpg
# data/images/image_03112.jpg -> dataset/train/image_03112.jpg
# data/images/image_08956.jpg -> dataset/train/image_08956.jpg
# data/images/image_03643.jpg -> dataset/train/image_03643.jpg
# data/images/image_03530.jpg -> dataset/train/image_03530.jpg
# data/images/image_07266.jpg -> dataset/train/image_07266.jpg
# data/images/image_03578.jpg -> dataset/train/image_03578.jpg
# data/images/image_09980.jpg -> dataset/train/image_09980.jpg
# data/images/image_04735.jpg -> dataset/train/image_04735.jpg
# data/images/image_09873.jpg -> dataset/train/image_09873.jpg
# data/images/image_03334.jpg -> dataset/train/image_03334.jpg
# data/images/image_09503.jpg -> dataset/train/image_09503.jpg
# data/images/image_03213.jpg -> dataset/train/image_03213.jpg
# data/images/image_06283.jpg -> dataset/train/image_06283.jpg
# data/images/image_04993.jpg -> dataset/train/image_04993.jpg
# data/images/image_00024.jpg -> dataset/train/image_00024.jpg
# data/images/image_02351.jpg -> dataset/train/image_02351.jpg
# data/images/image_07905.jpg -> dataset/train/image_07905.jpg
# data/images/image_04034.jpg -> dataset/train/image_04034.jpg
# data/images/image_02421.jpg -> dataset/train/image_02421.jpg
# data/images/image_05203.jpg -> dataset/train/image_05203.jpg
# data/images/image_02664.jpg -> dataset/train/image_02664.jpg
# data/images/image_02168.jpg -> dataset/train/image_02168.jpg
# data/images/image_05594.jpg -> dataset/train/image_05594.jpg
# data/images/image_04216.jpg -> dataset/train/image_04216.jpg
# data/images/image_02214.jpg -> dataset/train/image_02214.jpg
# data/images/image_04872.jpg -> dataset/train/image_04872.jpg
# data/images/image_09817.jpg -> dataset/train/image_09817.jpg
# data/images/image_06248.jpg -> dataset/train/image_06248.jpg
# data/images/image_09269.jpg -> dataset/train/image_09269.jpg
# data/images/image_06310.jpg -> dataset/train/image_06310.jpg
# data/images/image_05538.jpg -> dataset/train/image_05538.jpg
# data/images/image_01733.jpg -> dataset/train/image_01733.jpg
# data/images/image_03779.jpg -> dataset/train/image_03779.jpg
# data/images/image_05014.jpg -> dataset/train/image_05014.jpg
# data/images/image_05249.jpg -> dataset/train/image_05249.jpg
# data/images/image_05664.jpg -> dataset/train/image_05664.jpg
# data/images/image_01376.jpg -> dataset/train/image_01376.jpg
# data/images/image_09336.jpg -> dataset/train/image_09336.jpg
# data/images/image_00181.jpg -> dataset/train/image_00181.jpg
# data/images/image_02718.jpg -> dataset/train/image_02718.jpg
# data/images/image_06354.jpg -> dataset/train/image_06354.jpg
# data/images/image_06993.jpg -> dataset/train/image_06993.jpg
# data/images/image_03337.jpg -> dataset/train/image_03337.jpg
# data/images/image_07750.jpg -> dataset/train/image_07750.jpg
# data/images/image_01629.jpg -> dataset/train/image_01629.jpg
# data/images/image_03734.jpg -> dataset/train/image_03734.jpg
# data/images/image_06824.jpg -> dataset/train/image_06824.jpg
# data/images/image_03253.jpg -> dataset/train/image_03253.jpg
# data/images/image_00086.jpg -> dataset/train/image_00086.jpg
# data/images/image_08128.jpg -> dataset/train/image_08128.jpg
# data/images/image_02827.jpg -> dataset/train/image_02827.jpg
# data/images/image_04112.jpg -> dataset/train/image_04112.jpg
# data/images/image_08889.jpg -> dataset/train/image_08889.jpg
# data/images/image_01410.jpg -> dataset/train/image_01410.jpg
# data/images/image_03760.jpg -> dataset/train/image_03760.jpg
# data/images/image_01014.jpg -> dataset/train/image_01014.jpg
# data/images/image_07989.jpg -> dataset/train/image_07989.jpg
# data/images/image_00067.jpg -> dataset/train/image_00067.jpg
# data/images/image_04512.jpg -> dataset/train/image_04512.jpg
# data/images/image_09126.jpg -> dataset/train/image_09126.jpg
# data/images/image_01659.jpg -> dataset/train/image_01659.jpg
# data/images/image_03847.jpg -> dataset/train/image_03847.jpg
# data/images/image_05695.jpg -> dataset/train/image_05695.jpg
# data/images/image_03858.jpg -> dataset/train/image_03858.jpg
# data/images/image_01132.jpg -> dataset/train/image_01132.jpg
# data/images/image_05929.jpg -> dataset/train/image_05929.jpg
# data/images/image_04084.jpg -> dataset/train/image_04084.jpg
# data/images/image_04329.jpg -> dataset/train/image_04329.jpg
# data/images/image_03481.jpg -> dataset/train/image_03481.jpg
# data/images/image_07532.jpg -> dataset/train/image_07532.jpg
# data/images/image_00566.jpg -> dataset/train/image_00566.jpg
# data/images/image_06045.jpg -> dataset/train/image_06045.jpg
# data/images/image_05393.jpg -> dataset/train/image_05393.jpg
# data/images/image_07785.jpg -> dataset/train/image_07785.jpg
# data/images/image_03204.jpg -> dataset/train/image_03204.jpg
# data/images/image_02824.jpg -> dataset/train/image_02824.jpg
# data/images/image_07188.jpg -> dataset/train/image_07188.jpg
# data/images/image_09646.jpg -> dataset/train/image_09646.jpg
# data/images/image_07043.jpg -> dataset/train/image_07043.jpg
# data/images/image_03281.jpg -> dataset/train/image_03281.jpg
# data/images/image_05996.jpg -> dataset/train/image_05996.jpg
# data/images/image_03027.jpg -> dataset/train/image_03027.jpg
# data/images/image_02806.jpg -> dataset/train/image_02806.jpg
# data/images/image_03050.jpg -> dataset/train/image_03050.jpg
# data/images/image_03767.jpg -> dataset/train/image_03767.jpg
# data/images/image_05660.jpg -> dataset/train/image_05660.jpg
# data/images/image_03914.jpg -> dataset/train/image_03914.jpg
# data/images/image_01021.jpg -> dataset/train/image_01021.jpg
# data/images/image_02561.jpg -> dataset/train/image_02561.jpg
# data/images/image_00524.jpg -> dataset/train/image_00524.jpg
# data/images/image_00211.jpg -> dataset/train/image_00211.jpg
# data/images/image_01550.jpg -> dataset/train/image_01550.jpg
# data/images/image_01754.jpg -> dataset/train/image_01754.jpg
# data/images/image_01771.jpg -> dataset/train/image_01771.jpg
# data/images/image_08925.jpg -> dataset/train/image_08925.jpg
# data/images/image_02474.jpg -> dataset/train/image_02474.jpg
# data/images/image_05593.jpg -> dataset/train/image_05593.jpg
# data/images/image_06519.jpg -> dataset/train/image_06519.jpg
# data/images/image_06565.jpg -> dataset/train/image_06565.jpg
# data/images/image_06356.jpg -> dataset/train/image_06356.jpg
# data/images/image_02781.jpg -> dataset/train/image_02781.jpg
# data/images/image_05292.jpg -> dataset/train/image_05292.jpg
# data/images/image_02270.jpg -> dataset/train/image_02270.jpg
# data/images/image_00574.jpg -> dataset/train/image_00574.jpg
# data/images/image_02098.jpg -> dataset/train/image_02098.jpg
# data/images/image_05449.jpg -> dataset/train/image_05449.jpg
# data/images/image_04908.jpg -> dataset/train/image_04908.jpg
# data/images/image_04516.jpg -> dataset/train/image_04516.jpg
# data/images/image_00477.jpg -> dataset/train/image_00477.jpg
# data/images/image_07230.jpg -> dataset/train/image_07230.jpg
# data/images/image_09872.jpg -> dataset/train/image_09872.jpg
# data/images/image_08820.jpg -> dataset/train/image_08820.jpg
# data/images/image_00234.jpg -> dataset/train/image_00234.jpg
# data/images/image_02410.jpg -> dataset/train/image_02410.jpg
# data/images/image_03306.jpg -> dataset/train/image_03306.jpg
# data/images/image_08192.jpg -> dataset/train/image_08192.jpg
# data/images/image_01894.jpg -> dataset/train/image_01894.jpg
# data/images/image_03613.jpg -> dataset/train/image_03613.jpg
# data/images/image_01726.jpg -> dataset/train/image_01726.jpg
# data/images/image_09757.jpg -> dataset/train/image_09757.jpg
# data/images/image_08965.jpg -> dataset/train/image_08965.jpg
# data/images/image_09901.jpg -> dataset/train/image_09901.jpg
# data/images/image_04700.jpg -> dataset/train/image_04700.jpg
# data/images/image_08496.jpg -> dataset/train/image_08496.jpg
# data/images/image_03195.jpg -> dataset/train/image_03195.jpg
# data/images/image_02586.jpg -> dataset/train/image_02586.jpg
# data/images/image_02543.jpg -> dataset/train/image_02543.jpg
# data/images/image_01767.jpg -> dataset/train/image_01767.jpg
# data/images/image_04404.jpg -> dataset/train/image_04404.jpg
# data/images/image_03925.jpg -> dataset/train/image_03925.jpg
# data/images/image_00844.jpg -> dataset/train/image_00844.jpg
# data/images/image_03821.jpg -> dataset/train/image_03821.jpg
# data/images/image_06369.jpg -> dataset/train/image_06369.jpg
# data/images/image_05381.jpg -> dataset/train/image_05381.jpg
# data/images/image_04707.jpg -> dataset/train/image_04707.jpg
# data/images/image_08364.jpg -> dataset/train/image_08364.jpg
# data/images/image_05494.jpg -> dataset/train/image_05494.jpg
# data/images/image_09912.jpg -> dataset/train/image_09912.jpg
# data/images/image_00813.jpg -> dataset/train/image_00813.jpg
# data/images/image_00921.jpg -> dataset/train/image_00921.jpg
# data/images/image_09484.jpg -> dataset/train/image_09484.jpg
# data/images/image_00136.jpg -> dataset/train/image_00136.jpg
# data/images/image_02090.jpg -> dataset/train/image_02090.jpg
# data/images/image_05705.jpg -> dataset/train/image_05705.jpg
# data/images/image_02143.jpg -> dataset/train/image_02143.jpg
# data/images/image_01870.jpg -> dataset/train/image_01870.jpg
# data/images/image_00093.jpg -> dataset/train/image_00093.jpg
# data/images/image_01094.jpg -> dataset/train/image_01094.jpg
# data/images/image_06344.jpg -> dataset/train/image_06344.jpg
# data/images/image_00456.jpg -> dataset/train/image_00456.jpg
# data/images/image_07645.jpg -> dataset/train/image_07645.jpg
# data/images/image_09281.jpg -> dataset/train/image_09281.jpg
# data/images/image_01984.jpg -> dataset/train/image_01984.jpg
# data/images/image_03354.jpg -> dataset/train/image_03354.jpg
# data/images/image_08070.jpg -> dataset/train/image_08070.jpg
# data/images/image_07162.jpg -> dataset/train/image_07162.jpg
# data/images/image_09891.jpg -> dataset/train/image_09891.jpg
# data/images/image_01437.jpg -> dataset/train/image_01437.jpg
# data/images/image_05931.jpg -> dataset/train/image_05931.jpg
# data/images/image_00784.jpg -> dataset/train/image_00784.jpg
# data/images/image_05623.jpg -> dataset/train/image_05623.jpg
# data/images/image_06911.jpg -> dataset/train/image_06911.jpg
# data/images/image_09247.jpg -> dataset/train/image_09247.jpg
# data/images/image_08177.jpg -> dataset/train/image_08177.jpg
# data/images/image_07503.jpg -> dataset/train/image_07503.jpg
# data/images/image_00358.jpg -> dataset/train/image_00358.jpg
# data/images/image_05419.jpg -> dataset/train/image_05419.jpg
# data/images/image_09557.jpg -> dataset/train/image_09557.jpg
# data/images/image_06191.jpg -> dataset/train/image_06191.jpg
# data/images/image_09041.jpg -> dataset/train/image_09041.jpg
# data/images/image_08323.jpg -> dataset/train/image_08323.jpg
# data/images/image_02095.jpg -> dataset/train/image_02095.jpg
# data/images/image_09673.jpg -> dataset/train/image_09673.jpg
# data/images/image_00052.jpg -> dataset/train/image_00052.jpg
# data/images/image_06968.jpg -> dataset/train/image_06968.jpg
# data/images/image_00457.jpg -> dataset/train/image_00457.jpg
# data/images/image_03387.jpg -> dataset/train/image_03387.jpg
# data/images/image_00592.jpg -> dataset/train/image_00592.jpg
# data/images/image_05894.jpg -> dataset/train/image_05894.jpg
# data/images/image_03753.jpg -> dataset/train/image_03753.jpg
# data/images/image_04671.jpg -> dataset/train/image_04671.jpg
# data/images/image_00427.jpg -> dataset/train/image_00427.jpg
# data/images/image_02959.jpg -> dataset/train/image_02959.jpg
# data/images/image_05294.jpg -> dataset/train/image_05294.jpg
# data/images/image_05172.jpg -> dataset/train/image_05172.jpg
# data/images/image_06798.jpg -> dataset/train/image_06798.jpg
# data/images/image_00113.jpg -> dataset/train/image_00113.jpg
# data/images/image_07507.jpg -> dataset/train/image_07507.jpg
# data/images/image_08003.jpg -> dataset/train/image_08003.jpg
# data/images/image_05075.jpg -> dataset/train/image_05075.jpg
# data/images/image_07500.jpg -> dataset/train/image_07500.jpg
# data/images/image_07182.jpg -> dataset/train/image_07182.jpg
# data/images/image_04155.jpg -> dataset/train/image_04155.jpg
# data/images/image_07509.jpg -> dataset/train/image_07509.jpg
# data/images/image_05596.jpg -> dataset/train/image_05596.jpg
# data/images/image_04646.jpg -> dataset/train/image_04646.jpg
# data/images/image_05218.jpg -> dataset/train/image_05218.jpg
# data/images/image_04174.jpg -> dataset/train/image_04174.jpg
# data/images/image_03902.jpg -> dataset/train/image_03902.jpg
# data/images/image_07665.jpg -> dataset/train/image_07665.jpg
# data/images/image_04460.jpg -> dataset/train/image_04460.jpg
# data/images/image_04771.jpg -> dataset/train/image_04771.jpg
# data/images/image_09153.jpg -> dataset/train/image_09153.jpg
# data/images/image_06900.jpg -> dataset/train/image_06900.jpg
# data/images/image_04606.jpg -> dataset/train/image_04606.jpg
# data/images/image_08812.jpg -> dataset/train/image_08812.jpg
# data/images/image_00421.jpg -> dataset/train/image_00421.jpg
# data/images/image_00523.jpg -> dataset/train/image_00523.jpg
# data/images/image_07383.jpg -> dataset/train/image_07383.jpg
# data/images/image_09996.jpg -> dataset/train/image_09996.jpg
# data/images/image_01817.jpg -> dataset/train/image_01817.jpg
# data/images/image_02724.jpg -> dataset/train/image_02724.jpg
# data/images/image_01208.jpg -> dataset/train/image_01208.jpg
# data/images/image_05033.jpg -> dataset/train/image_05033.jpg
# data/images/image_08251.jpg -> dataset/train/image_08251.jpg
# data/images/image_07490.jpg -> dataset/train/image_07490.jpg
# data/images/image_01561.jpg -> dataset/train/image_01561.jpg
# data/images/image_07064.jpg -> dataset/train/image_07064.jpg
# data/images/image_09044.jpg -> dataset/train/image_09044.jpg
# data/images/image_01293.jpg -> dataset/train/image_01293.jpg
# data/images/image_09987.jpg -> dataset/train/image_09987.jpg
# data/images/image_00820.jpg -> dataset/train/image_00820.jpg
# data/images/image_08196.jpg -> dataset/train/image_08196.jpg
# data/images/image_01451.jpg -> dataset/train/image_01451.jpg
# data/images/image_06135.jpg -> dataset/train/image_06135.jpg
# data/images/image_02924.jpg -> dataset/train/image_02924.jpg
# data/images/image_01579.jpg -> dataset/train/image_01579.jpg
# data/images/image_00702.jpg -> dataset/train/image_00702.jpg
# data/images/image_09811.jpg -> dataset/train/image_09811.jpg
# data/images/image_05500.jpg -> dataset/train/image_05500.jpg
# data/images/image_02347.jpg -> dataset/train/image_02347.jpg
# data/images/image_07430.jpg -> dataset/train/image_07430.jpg
# data/images/image_07226.jpg -> dataset/train/image_07226.jpg
# data/images/image_05071.jpg -> dataset/train/image_05071.jpg
# data/images/image_04213.jpg -> dataset/train/image_04213.jpg
# data/images/image_09263.jpg -> dataset/train/image_09263.jpg
# data/images/image_08688.jpg -> dataset/train/image_08688.jpg
# data/images/image_05584.jpg -> dataset/train/image_05584.jpg
# data/images/image_08853.jpg -> dataset/train/image_08853.jpg
# data/images/image_04861.jpg -> dataset/train/image_04861.jpg
# data/images/image_04912.jpg -> dataset/train/image_04912.jpg
# data/images/image_09278.jpg -> dataset/train/image_09278.jpg
# data/images/image_04252.jpg -> dataset/train/image_04252.jpg
# data/images/image_04794.jpg -> dataset/train/image_04794.jpg
# data/images/image_07480.jpg -> dataset/train/image_07480.jpg
# data/images/image_03548.jpg -> dataset/train/image_03548.jpg
# data/images/image_05962.jpg -> dataset/train/image_05962.jpg
# data/images/image_07976.jpg -> dataset/train/image_07976.jpg
# data/images/image_00345.jpg -> dataset/train/image_00345.jpg
# data/images/image_05639.jpg -> dataset/train/image_05639.jpg
# data/images/image_06073.jpg -> dataset/train/image_06073.jpg
# data/images/image_05848.jpg -> dataset/train/image_05848.jpg
# data/images/image_03367.jpg -> dataset/train/image_03367.jpg
# data/images/image_05341.jpg -> dataset/train/image_05341.jpg
# data/images/image_08549.jpg -> dataset/train/image_08549.jpg
# data/images/image_03871.jpg -> dataset/train/image_03871.jpg
# data/images/image_09170.jpg -> dataset/train/image_09170.jpg
# data/images/image_01034.jpg -> dataset/train/image_01034.jpg
# data/images/image_06873.jpg -> dataset/train/image_06873.jpg
# data/images/image_02529.jpg -> dataset/train/image_02529.jpg
# data/images/image_08148.jpg -> dataset/train/image_08148.jpg
# data/images/image_05739.jpg -> dataset/train/image_05739.jpg
# data/images/image_09423.jpg -> dataset/train/image_09423.jpg
# data/images/image_06572.jpg -> dataset/train/image_06572.jpg
# data/images/image_05646.jpg -> dataset/train/image_05646.jpg
# data/images/image_07533.jpg -> dataset/train/image_07533.jpg
# data/images/image_05988.jpg -> dataset/train/image_05988.jpg
# data/images/image_00803.jpg -> dataset/train/image_00803.jpg
# data/images/image_05425.jpg -> dataset/train/image_05425.jpg
# data/images/image_05543.jpg -> dataset/train/image_05543.jpg
# data/images/image_04619.jpg -> dataset/train/image_04619.jpg
# data/images/image_07227.jpg -> dataset/train/image_07227.jpg
# data/images/image_09935.jpg -> dataset/train/image_09935.jpg
# data/images/image_00059.jpg -> dataset/train/image_00059.jpg
# data/images/image_05539.jpg -> dataset/train/image_05539.jpg
# data/images/image_09020.jpg -> dataset/train/image_09020.jpg
# data/images/image_06317.jpg -> dataset/train/image_06317.jpg
# data/images/image_05255.jpg -> dataset/train/image_05255.jpg
# data/images/image_06912.jpg -> dataset/train/image_06912.jpg
# data/images/image_02166.jpg -> dataset/train/image_02166.jpg
# data/images/image_09958.jpg -> dataset/train/image_09958.jpg
# data/images/image_09289.jpg -> dataset/train/image_09289.jpg
# data/images/image_01248.jpg -> dataset/train/image_01248.jpg
# data/images/image_01613.jpg -> dataset/train/image_01613.jpg
# data/images/image_04140.jpg -> dataset/train/image_04140.jpg
# data/images/image_01053.jpg -> dataset/train/image_01053.jpg
# data/images/image_04387.jpg -> dataset/train/image_04387.jpg
# data/images/image_05592.jpg -> dataset/train/image_05592.jpg
# data/images/image_01075.jpg -> dataset/train/image_01075.jpg
# data/images/image_09160.jpg -> dataset/train/image_09160.jpg
# data/images/image_01764.jpg -> dataset/train/image_01764.jpg
# data/images/image_05031.jpg -> dataset/train/image_05031.jpg
# data/images/image_00010.jpg -> dataset/train/image_00010.jpg
# data/images/image_02448.jpg -> dataset/train/image_02448.jpg
# data/images/image_01238.jpg -> dataset/train/image_01238.jpg
# data/images/image_03277.jpg -> dataset/train/image_03277.jpg
# data/images/image_06992.jpg -> dataset/train/image_06992.jpg
# data/images/image_03834.jpg -> dataset/train/image_03834.jpg
# data/images/image_05586.jpg -> dataset/train/image_05586.jpg
# data/images/image_07743.jpg -> dataset/train/image_07743.jpg
# data/images/image_04600.jpg -> dataset/train/image_04600.jpg
# data/images/image_01532.jpg -> dataset/train/image_01532.jpg
# data/images/image_06172.jpg -> dataset/train/image_06172.jpg
# data/images/image_04356.jpg -> dataset/train/image_04356.jpg
# data/images/image_05018.jpg -> dataset/train/image_05018.jpg
# data/images/image_08194.jpg -> dataset/train/image_08194.jpg
# data/images/image_01504.jpg -> dataset/train/image_01504.jpg
# data/images/image_03744.jpg -> dataset/train/image_03744.jpg
# data/images/image_06870.jpg -> dataset/train/image_06870.jpg
# data/images/image_03953.jpg -> dataset/train/image_03953.jpg
# data/images/image_03138.jpg -> dataset/train/image_03138.jpg
# data/images/image_01908.jpg -> dataset/train/image_01908.jpg
# data/images/image_04123.jpg -> dataset/train/image_04123.jpg
# data/images/image_00285.jpg -> dataset/train/image_00285.jpg
# data/images/image_04295.jpg -> dataset/train/image_04295.jpg
# data/images/image_00188.jpg -> dataset/train/image_00188.jpg
# ...
# data/images/image_01356.jpg -> dataset/test/image_01356.jpg
# data/images/image_06705.jpg -> dataset/test/image_06705.jpg
# data/images/image_06622.jpg -> dataset/test/image_06622.jpg
# data/images/image_08972.jpg -> dataset/test/image_08972.jpg
# data/images/image_05339.jpg -> dataset/test/image_05339.jpg
# data/images/image_04941.jpg -> dataset/test/image_04941.jpg
# data/images/image_02193.jpg -> dataset/test/image_02193.jpg
# data/images/image_07354.jpg -> dataset/test/image_07354.jpg
# data/images/image_03391.jpg -> dataset/test/image_03391.jpg
# data/images/image_04438.jpg -> dataset/test/image_04438.jpg
# data/images/image_08103.jpg -> dataset/test/image_08103.jpg
# data/images/image_06154.jpg -> dataset/test/image_06154.jpg
# data/images/image_06869.jpg -> dataset/test/image_06869.jpg
# data/images/image_09413.jpg -> dataset/test/image_09413.jpg
# data/images/image_07891.jpg -> dataset/test/image_07891.jpg
# data/images/image_05475.jpg -> dataset/test/image_05475.jpg
# data/images/image_02697.jpg -> dataset/test/image_02697.jpg
# data/images/image_09778.jpg -> dataset/test/image_09778.jpg
# data/images/image_06101.jpg -> dataset/test/image_06101.jpg
# data/images/image_03302.jpg -> dataset/test/image_03302.jpg
# data/images/image_09745.jpg -> dataset/test/image_09745.jpg
# data/images/image_05094.jpg -> dataset/test/image_05094.jpg
# data/images/image_09661.jpg -> dataset/test/image_09661.jpg
# data/images/image_05700.jpg -> dataset/test/image_05700.jpg
# data/images/image_03788.jpg -> dataset/test/image_03788.jpg
# data/images/image_03808.jpg -> dataset/test/image_03808.jpg
# data/images/image_09120.jpg -> dataset/test/image_09120.jpg
# data/images/image_03653.jpg -> dataset/test/image_03653.jpg
# data/images/image_01496.jpg -> dataset/test/image_01496.jpg
# data/images/image_02280.jpg -> dataset/test/image_02280.jpg
# data/images/image_09647.jpg -> dataset/test/image_09647.jpg
# data/images/image_00296.jpg -> dataset/test/image_00296.jpg
# data/images/image_01573.jpg -> dataset/test/image_01573.jpg
# data/images/image_05238.jpg -> dataset/test/image_05238.jpg
# data/images/image_00251.jpg -> dataset/test/image_00251.jpg
# data/images/image_04178.jpg -> dataset/test/image_04178.jpg
# data/images/image_08359.jpg -> dataset/test/image_08359.jpg
# data/images/image_01421.jpg -> dataset/test/image_01421.jpg
# data/images/image_00334.jpg -> dataset/test/image_00334.jpg
# data/images/image_01610.jpg -> dataset/test/image_01610.jpg
# data/images/image_05090.jpg -> dataset/test/image_05090.jpg
# data/images/image_01266.jpg -> dataset/test/image_01266.jpg
# data/images/image_00383.jpg -> dataset/test/image_00383.jpg
# data/images/image_01346.jpg -> dataset/test/image_01346.jpg
# data/images/image_06945.jpg -> dataset/test/image_06945.jpg
# data/images/image_06850.jpg -> dataset/test/image_06850.jpg
# data/images/image_07092.jpg -> dataset/test/image_07092.jpg
# data/images/image_02093.jpg -> dataset/test/image_02093.jpg
# data/images/image_09328.jpg -> dataset/test/image_09328.jpg
# data/images/image_03247.jpg -> dataset/test/image_03247.jpg
# data/images/image_06863.jpg -> dataset/test/image_06863.jpg
# data/images/image_06009.jpg -> dataset/test/image_06009.jpg
# data/images/image_05935.jpg -> dataset/test/image_05935.jpg
# data/images/image_04177.jpg -> dataset/test/image_04177.jpg
# data/images/image_04275.jpg -> dataset/test/image_04275.jpg
# data/images/image_07738.jpg -> dataset/test/image_07738.jpg
# data/images/image_01803.jpg -> dataset/test/image_01803.jpg
# data/images/image_06879.jpg -> dataset/test/image_06879.jpg
# data/images/image_07035.jpg -> dataset/test/image_07035.jpg
# data/images/image_07504.jpg -> dataset/test/image_07504.jpg
# data/images/image_05777.jpg -> dataset/test/image_05777.jpg
# data/images/image_01375.jpg -> dataset/test/image_01375.jpg
# data/images/image_08519.jpg -> dataset/test/image_08519.jpg
# data/images/image_05656.jpg -> dataset/test/image_05656.jpg
# data/images/image_07292.jpg -> dataset/test/image_07292.jpg
# data/images/image_00647.jpg -> dataset/test/image_00647.jpg
# data/images/image_03780.jpg -> dataset/test/image_03780.jpg
# data/images/image_09157.jpg -> dataset/test/image_09157.jpg
# data/images/image_02730.jpg -> dataset/test/image_02730.jpg
# data/images/image_03619.jpg -> dataset/test/image_03619.jpg
# data/images/image_02791.jpg -> dataset/test/image_02791.jpg
# data/images/image_09758.jpg -> dataset/test/image_09758.jpg
# data/images/image_04119.jpg -> dataset/test/image_04119.jpg
# data/images/image_00546.jpg -> dataset/test/image_00546.jpg
# data/images/image_04929.jpg -> dataset/test/image_04929.jpg
# data/images/image_06943.jpg -> dataset/test/image_06943.jpg
# data/images/image_00797.jpg -> dataset/test/image_00797.jpg
# data/images/image_09173.jpg -> dataset/test/image_09173.jpg
# data/images/image_09178.jpg -> dataset/test/image_09178.jpg
# data/images/image_01245.jpg -> dataset/test/image_01245.jpg
# data/images/image_09385.jpg -> dataset/test/image_09385.jpg
# data/images/image_08214.jpg -> dataset/test/image_08214.jpg
# data/images/image_09642.jpg -> dataset/test/image_09642.jpg
# data/images/image_05722.jpg -> dataset/test/image_05722.jpg
# data/images/image_04497.jpg -> dataset/test/image_04497.jpg
# data/images/image_01490.jpg -> dataset/test/image_01490.jpg
# data/images/image_05503.jpg -> dataset/test/image_05503.jpg
# data/images/image_07620.jpg -> dataset/test/image_07620.jpg
# data/images/image_00391.jpg -> dataset/test/image_00391.jpg
# data/images/image_07237.jpg -> dataset/test/image_07237.jpg
# data/images/image_07779.jpg -> dataset/test/image_07779.jpg
# data/images/image_08692.jpg -> dataset/test/image_08692.jpg
# data/images/image_07793.jpg -> dataset/test/image_07793.jpg
# data/images/image_02088.jpg -> dataset/test/image_02088.jpg
# data/images/image_08245.jpg -> dataset/test/image_08245.jpg
# data/images/image_06638.jpg -> dataset/test/image_06638.jpg
# data/images/image_09135.jpg -> dataset/test/image_09135.jpg
# data/images/image_01592.jpg -> dataset/test/image_01592.jpg
# data/images/image_05478.jpg -> dataset/test/image_05478.jpg
# data/images/image_09722.jpg -> dataset/test/image_09722.jpg
# data/images/image_08550.jpg -> dataset/test/image_08550.jpg
# data/images/image_01584.jpg -> dataset/test/image_01584.jpg
# data/images/image_03051.jpg -> dataset/test/image_03051.jpg
# data/images/image_09609.jpg -> dataset/test/image_09609.jpg
# data/images/image_09302.jpg -> dataset/test/image_09302.jpg
# data/images/image_05225.jpg -> dataset/test/image_05225.jpg
# data/images/image_09357.jpg -> dataset/test/image_09357.jpg
# data/images/image_02974.jpg -> dataset/test/image_02974.jpg
# data/images/image_01948.jpg -> dataset/test/image_01948.jpg
# data/images/image_07062.jpg -> dataset/test/image_07062.jpg
# data/images/image_08748.jpg -> dataset/test/image_08748.jpg
# data/images/image_05299.jpg -> dataset/test/image_05299.jpg
# data/images/image_01423.jpg -> dataset/test/image_01423.jpg
# data/images/image_03798.jpg -> dataset/test/image_03798.jpg
# data/images/image_01508.jpg -> dataset/test/image_01508.jpg
# data/images/image_06882.jpg -> dataset/test/image_06882.jpg
# data/images/image_04298.jpg -> dataset/test/image_04298.jpg
# data/images/image_05246.jpg -> dataset/test/image_05246.jpg
# data/images/image_03903.jpg -> dataset/test/image_03903.jpg
# data/images/image_01466.jpg -> dataset/test/image_01466.jpg
# data/images/image_03828.jpg -> dataset/test/image_03828.jpg
# data/images/image_06670.jpg -> dataset/test/image_06670.jpg
# data/images/image_03269.jpg -> dataset/test/image_03269.jpg
# data/images/image_07335.jpg -> dataset/test/image_07335.jpg
# data/images/image_08261.jpg -> dataset/test/image_08261.jpg
# data/images/image_05009.jpg -> dataset/test/image_05009.jpg
# data/images/image_01025.jpg -> dataset/test/image_01025.jpg
# data/images/image_08313.jpg -> dataset/test/image_08313.jpg
# data/images/image_01420.jpg -> dataset/test/image_01420.jpg
# data/images/image_02469.jpg -> dataset/test/image_02469.jpg
# data/images/image_01391.jpg -> dataset/test/image_01391.jpg
# data/images/image_01926.jpg -> dataset/test/image_01926.jpg
# data/images/image_04091.jpg -> dataset/test/image_04091.jpg
# data/images/image_02527.jpg -> dataset/test/image_02527.jpg
# data/images/image_08641.jpg -> dataset/test/image_08641.jpg
# data/images/image_05413.jpg -> dataset/test/image_05413.jpg
# data/images/image_05156.jpg -> dataset/test/image_05156.jpg
# data/images/image_00493.jpg -> dataset/test/image_00493.jpg
# data/images/image_02539.jpg -> dataset/test/image_02539.jpg
# data/images/image_08230.jpg -> dataset/test/image_08230.jpg
# data/images/image_07760.jpg -> dataset/test/image_07760.jpg
# data/images/image_01151.jpg -> dataset/test/image_01151.jpg
# data/images/image_08589.jpg -> dataset/test/image_08589.jpg
# data/images/image_06093.jpg -> dataset/test/image_06093.jpg
# data/images/image_09683.jpg -> dataset/test/image_09683.jpg
# data/images/image_05720.jpg -> dataset/test/image_05720.jpg
# data/images/image_02290.jpg -> dataset/test/image_02290.jpg
# data/images/image_02251.jpg -> dataset/test/image_02251.jpg
# data/images/image_09918.jpg -> dataset/test/image_09918.jpg
# data/images/image_00863.jpg -> dataset/test/image_00863.jpg
# data/images/image_00480.jpg -> dataset/test/image_00480.jpg
# data/images/image_09376.jpg -> dataset/test/image_09376.jpg
# data/images/image_06795.jpg -> dataset/test/image_06795.jpg
# data/images/image_09519.jpg -> dataset/test/image_09519.jpg
# data/images/image_04748.jpg -> dataset/test/image_04748.jpg
# data/images/image_04068.jpg -> dataset/test/image_04068.jpg
# data/images/image_07602.jpg -> dataset/test/image_07602.jpg
# data/images/image_04272.jpg -> dataset/test/image_04272.jpg
# data/images/image_06382.jpg -> dataset/test/image_06382.jpg
# data/images/image_05879.jpg -> dataset/test/image_05879.jpg
# data/images/image_04570.jpg -> dataset/test/image_04570.jpg
# data/images/image_08776.jpg -> dataset/test/image_08776.jpg
# data/images/image_00413.jpg -> dataset/test/image_00413.jpg
# data/images/image_02501.jpg -> dataset/test/image_02501.jpg
# data/images/image_02716.jpg -> dataset/test/image_02716.jpg
# data/images/image_09189.jpg -> dataset/test/image_09189.jpg
# data/images/image_09788.jpg -> dataset/test/image_09788.jpg
# data/images/image_03770.jpg -> dataset/test/image_03770.jpg
# data/images/image_02475.jpg -> dataset/test/image_02475.jpg
# data/images/image_03378.jpg -> dataset/test/image_03378.jpg
# data/images/image_00272.jpg -> dataset/test/image_00272.jpg
# data/images/image_01867.jpg -> dataset/test/image_01867.jpg
# data/images/image_01802.jpg -> dataset/test/image_01802.jpg
# data/images/image_06835.jpg -> dataset/test/image_06835.jpg
# data/images/image_06436.jpg -> dataset/test/image_06436.jpg
# data/images/image_08821.jpg -> dataset/test/image_08821.jpg
# data/images/image_08864.jpg -> dataset/test/image_08864.jpg
# data/images/image_04215.jpg -> dataset/test/image_04215.jpg
# data/images/image_04238.jpg -> dataset/test/image_04238.jpg
# data/images/image_00500.jpg -> dataset/test/image_00500.jpg
# data/images/image_01230.jpg -> dataset/test/image_01230.jpg
# data/images/image_07323.jpg -> dataset/test/image_07323.jpg
# data/images/image_06007.jpg -> dataset/test/image_06007.jpg
# data/images/image_00226.jpg -> dataset/test/image_00226.jpg
# data/images/image_03944.jpg -> dataset/test/image_03944.jpg
# data/images/image_01072.jpg -> dataset/test/image_01072.jpg
# data/images/image_05934.jpg -> dataset/test/image_05934.jpg
# data/images/image_09215.jpg -> dataset/test/image_09215.jpg
# data/images/image_04672.jpg -> dataset/test/image_04672.jpg
# data/images/image_00981.jpg -> dataset/test/image_00981.jpg
# data/images/image_01418.jpg -> dataset/test/image_01418.jpg
# data/images/image_05181.jpg -> dataset/test/image_05181.jpg
# data/images/image_05554.jpg -> dataset/test/image_05554.jpg
# data/images/image_08144.jpg -> dataset/test/image_08144.jpg
# data/images/image_02135.jpg -> dataset/test/image_02135.jpg
# data/images/image_01045.jpg -> dataset/test/image_01045.jpg
# data/images/image_04087.jpg -> dataset/test/image_04087.jpg
# data/images/image_00412.jpg -> dataset/test/image_00412.jpg
# data/images/image_09061.jpg -> dataset/test/image_09061.jpg
# data/images/image_01104.jpg -> dataset/test/image_01104.jpg
# data/images/image_07570.jpg -> dataset/test/image_07570.jpg
# data/images/image_00865.jpg -> dataset/test/image_00865.jpg
# data/images/image_01106.jpg -> dataset/test/image_01106.jpg
# data/images/image_05213.jpg -> dataset/test/image_05213.jpg
# data/images/image_01314.jpg -> dataset/test/image_01314.jpg
# data/images/image_00638.jpg -> dataset/test/image_00638.jpg
# data/images/image_04509.jpg -> dataset/test/image_04509.jpg
# data/images/image_04114.jpg -> dataset/test/image_04114.jpg
# data/images/image_03628.jpg -> dataset/test/image_03628.jpg
# data/images/image_05022.jpg -> dataset/test/image_05022.jpg
# data/images/image_04519.jpg -> dataset/test/image_04519.jpg
# data/images/image_07608.jpg -> dataset/test/image_07608.jpg
# data/images/image_05738.jpg -> dataset/test/image_05738.jpg
# data/images/image_02606.jpg -> dataset/test/image_02606.jpg
# data/images/image_03392.jpg -> dataset/test/image_03392.jpg
# data/images/image_01286.jpg -> dataset/test/image_01286.jpg
# data/images/image_00880.jpg -> dataset/test/image_00880.jpg
# data/images/image_09731.jpg -> dataset/test/image_09731.jpg
# data/images/image_03069.jpg -> dataset/test/image_03069.jpg
# data/images/image_04279.jpg -> dataset/test/image_04279.jpg
# data/images/image_09180.jpg -> dataset/test/image_09180.jpg
# data/images/image_00511.jpg -> dataset/test/image_00511.jpg
# data/images/image_04840.jpg -> dataset/test/image_04840.jpg
# data/images/image_08339.jpg -> dataset/test/image_08339.jpg
# data/images/image_03893.jpg -> dataset/test/image_03893.jpg
# data/images/image_01181.jpg -> dataset/test/image_01181.jpg
# data/images/image_01193.jpg -> dataset/test/image_01193.jpg
# data/images/image_08569.jpg -> dataset/test/image_08569.jpg
# data/images/image_04511.jpg -> dataset/test/image_04511.jpg
# data/images/image_06729.jpg -> dataset/test/image_06729.jpg
# data/images/image_07492.jpg -> dataset/test/image_07492.jpg
# data/images/image_05332.jpg -> dataset/test/image_05332.jpg
# data/images/image_01507.jpg -> dataset/test/image_01507.jpg
# data/images/image_01405.jpg -> dataset/test/image_01405.jpg
# data/images/image_00629.jpg -> dataset/test/image_00629.jpg
# data/images/image_00312.jpg -> dataset/test/image_00312.jpg
# data/images/image_06965.jpg -> dataset/test/image_06965.jpg
# data/images/image_02906.jpg -> dataset/test/image_02906.jpg
# data/images/image_09188.jpg -> dataset/test/image_09188.jpg
# data/images/image_03443.jpg -> dataset/test/image_03443.jpg
# data/images/image_08260.jpg -> dataset/test/image_08260.jpg
# data/images/image_02731.jpg -> dataset/test/image_02731.jpg
# data/images/image_07540.jpg -> dataset/test/image_07540.jpg
# data/images/image_00962.jpg -> dataset/test/image_00962.jpg
# data/images/image_01611.jpg -> dataset/test/image_01611.jpg
# data/images/image_04473.jpg -> dataset/test/image_04473.jpg
# data/images/image_01939.jpg -> dataset/test/image_01939.jpg
# data/images/image_08439.jpg -> dataset/test/image_08439.jpg
# data/images/image_04318.jpg -> dataset/test/image_04318.jpg
# data/images/image_05834.jpg -> dataset/test/image_05834.jpg
# data/images/image_05244.jpg -> dataset/test/image_05244.jpg
# data/images/image_06402.jpg -> dataset/test/image_06402.jpg
# data/images/image_00382.jpg -> dataset/test/image_00382.jpg
# data/images/image_06679.jpg -> dataset/test/image_06679.jpg
# data/images/image_08206.jpg -> dataset/test/image_08206.jpg
# data/images/image_04725.jpg -> dataset/test/image_04725.jpg
# data/images/image_05861.jpg -> dataset/test/image_05861.jpg
# data/images/image_06701.jpg -> dataset/test/image_06701.jpg
# data/images/image_01565.jpg -> dataset/test/image_01565.jpg
# data/images/image_06953.jpg -> dataset/test/image_06953.jpg
# data/images/image_08879.jpg -> dataset/test/image_08879.jpg
# data/images/image_05635.jpg -> dataset/test/image_05635.jpg
# ✅ Split complete! Results saved in 'dataset/'
# Train: 6000, Val: 2000, Test: 2000
# ✅ Created dataset/train/labels.csv with 6000 entries
# ✅ Created dataset/val/labels.csv with 2000 entries
# ✅ Created dataset/test/labels.csv with 2000 entries
